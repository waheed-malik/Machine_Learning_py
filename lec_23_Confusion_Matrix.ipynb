# %% [markdown]
# ### **Confusion Matrix**
#
# 1. A confusion matrix is a table used to evaluate the performance of a classification model by comparing its predictions with the actual outcomes. It’s especially useful in assessing the effectiveness of a model on multiclass or binary classification tasks

# %% [markdown]
# Suppose kry k ap ne 1 model bnaya hy or uski accurracy 95% hy or ap us model ko
# apne senior ya company owner ko dety hyn. or wo kia krty hyn k ap k model ko reject
# kr dety hyn. to ye rejection ka kaam confusion matrix ki base pr hota hy

# %%
from IPython.display import Image
Image(filename="confusion matrix.png")

# %% [markdown]
# ##### IS k zarye hum pta lgaty hyn k hmara model kitna acha trained hwa hy or
# ##### wo kitna acha prediction kry ga.

# %%
Image(filename="confusion matrix table.png")

# %%
Image(filename="confusion matrix detail1.png")

# %% [markdown]
# basically ye humy btata hy k
# 1. hmara model kitna acha
# 2. hmara model kaha pr wrong prediction kr raha hy
# 3. humy model ko kab or kese reject krna chahye.
#
# is matrix k through hum log yahi dekhty hyn k kitny 0 thy jis pr model ne 1 output di.
# or kitny 1 aise thy jis pr model ne 0 answer dya.
# mtlb k wrong predictions kitni hyn. or isi ki base pr phr hum model ko reject
# krty hyn. chahy accurracy 95% he q na ho.

# %%
Image(filename="confusion matrix create.png")

# %% [markdown]
# 1. 0 pr 0
# 2. 0 pr 1
# 3. 1 pr 0
# 4. 0 pr 1
#
# 2nd and 3rd case is difficult. yahan se actuall problem hmari start hoti hy.

# %%
Image(filename="type1_&_type2 erros.png")

# %%
from IPython.display import Image
Image(filename="confusion matrix practice.png")

# %% [markdown]
# ### *** If you want to decrease FN then increase recall. ***

# %% [markdown]
# ap ko company ka call letter email ai. or ap k model ne usko spam me daal dya.
# hala k wo spam nahi tha. to is ka result kia hwa k by mistake ap ne spam folder
# open kr k check he nahi kia. to apki job reh jae gi.
# is case me not spam ko spam btana hmary lye problem create kr skta hy(type-II eroor).
#
# - ab hmary pass 2no ki accuracy same hy 80%.
# - ab hum dekhy gy type-II error, because hmary is case me type-II error important hy.
# - model B select ho ga bcz is me not spam ko spam me dalny k total 10 mails hyn or model A me  30.

# %%
Image(filename="confusion matrix practice2.png")

# %% [markdown]
# ### ** If you want to decrease FP then increase precision **
#
#
# 1. FN ---> Recall increase
# 2. FP ---> Precision increase

# %%
Image(filename="f1_score.png")

# %% [markdown]
# - isi trhan humy kisi problem me recall or kisi me precision ko high krni pary gi.
#
# - lakin kahi aise cases bhi a skty hyn k humy 2no ka high krna pary.
# - or aisa bhi ho skta hy k hum decide na kr pa rahy hon k kis ko increase krna hy to
#   aise case me hum **f1** score ko dekhy gy. mtlb is ko high krna hy.
#   - precision or recall jitna ziyada ho ga hmara f1 score utna he ziyada ho ga.

# %% [markdown]
# ### Let's Practice

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("students_placement.csv")
ds.head(3)

# %%
x = ds[["cgpa", 'iq', 'score']]
y = ds["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=.20, random_state=70)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)

# %%
y_pred = lr.predict(x_test)

# %%
lr.score(x_test,y_test)*100

# %%
from sklearn.metrics import confusion_matrix, recall_score, precision_score,f1_score

# %%
cmr = confusion_matrix(y_test,y_pred)

# %%
#ds["placed"].value_counts()

# %%
sns.heatmap(data=cmr, annot=True)
plt.show()

# %%
precision_score(y_test,y_pred)*100

# %%
recall_score(y_test,y_pred)*100

# %%
f1_score(y_test,y_pred)*100
