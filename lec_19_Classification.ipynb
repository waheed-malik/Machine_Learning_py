# %% [markdown]
# ### classification
#
# -   Output data discrete nature ka hota hy

# %%
from IPython.display import Image

# %% [markdown]
# ## open Classification.pdf file

# %%
Image(filename="classificationExample.png")

# %%
Image(filename="classificationCostFunction.png")

# %%
Image(filename="typesOfClassificationAlgorithms.png")

# %%
Image(filename="linear_vs_non_linear_classification.JPG")
# linear model mean k linear line draw krne se classification ho jati hy

# %% [markdown]
# #### Logistic Regression and NaiveBayes sirf or sirf classification k lye use hoty hyn.
# #### jab k baki algorithms hum regression k lye bhi use kr skty hyn or classification k lye bhi,

# %%
Image(filename="classificationEvaluationMatrix.png")

# %% [markdown]
# For Binary classification cost function we use Binary Cross-Entropy (Log Loss):
#
# Multi-class classification cost function we use Categorical Cross-Entropy (Multi-class Cross-Entropy):

# %% [markdown]
# #### Evaluation Methods:
# it tells How well our model is working
#
# Log Loss or Cross Entropy:
# jo bhi model use krne ja rahy hyn us k losses ko nikalta hy. or gradient decent k through hmary pass output lany me help krta hy.
#
# Confusion Matrix: (The soul of classification)
# model acha bana lya, accuracy bhi achi hy. lakin phr bhi confusion matrix us ko reject kr deta hy.
#
# AUC-ROC Curve:
# it tells How well our model is working
