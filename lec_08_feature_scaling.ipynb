# %% [markdown]
# ### Feature Scaling
#
# hmary dataset me kuch values bari ho sakti hyn or kuch small . to jab hum data apne model ko
# train krne k lye use kry gy to model big values ko dominate krta mtlb unko use kr k model train kr
# deta hy. or small values ko less importance deta hy. mostly to aisa hota hy k small values ko zero
# importance deta hy. is lye phr hmy feature scalling krni prti hy.
#
# forexample :
#
#     big apple or small apple ( reduce big apple to small apple size) called feature scalling.
#
# Now question is that k
#     is se hmary data pr kia effect ho ga? mean data ki nature change ho jae gi ya nahi?
#
#     to answer hy k nahi. befor and after feature scalling jab hum normal distribution bnae gy to wahi results rahy gy jo pehly thy.
#
# Data ko training k lye use krne se pehly feature scaling lazmi krni chahye.
#
# Han is se data ka magnitude/pattern zror change ho jata. or magnitude me changing feature scalling technique pr depend krti hy. boht sary scalling techniques hyn. kuch un me se given hyn.
#
# ### Types of Feature Scalling
#
# - Standardization --> less affected by outliers
#
# - Normalization   --> affected by outliers

# %%
# feature scalling pics web link
# https://www.google.com/imgres?imgurl=https%3A%2F%2Fmedia.geeksforgeeks.org%2Fwp-content%2Fuploads%2F20221222013208%2FScreenshot_2022-12-22-01-31-04-96_4a24d271e133915ae237d4bec6ffe368.jpg&tbnid=rpzQ2yMQJaR58M&vet=12ahUKEwi_l-e00s2FAxViXqQEHexnB34QMygIegQIARBk..i&imgrefurl=https%3A%2F%2Fwww.geeksforgeeks.org%2Fpython-how-and-where-to-apply-feature-scaling%2F&docid=qOg-q2NSkSJlMM&w=1080&h=786&q=standardization%20in%20feature%20scaling&ved=2ahUKEwi_l-e00s2FAxViXqQEHexnB34QMygIegQIARBk#imgrc=rpzQ2yMQJaR58M&imgdii=1ckRmPKcTox5QM

# %% [markdown]
# - Standardization rescale values and
#
#     -    values has distribution between zero means and 1 variance.

# %%
from IPython.display import Image
Image(filename="standardization.png")

# %%
# feature scalling se outliers remove nahi hoty. han inka mag
Image(filename="featureScalling.png")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("loan.csv")
dataset.shape
# Out:
# (614, 13)

# %%
dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
sns.distplot(dataset["CoapplicantIncome"])
plt.show()
# Out:
# C:\Users\Aahil Khan\AppData\Local\Temp\ipykernel_23212\1899262194.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["CoapplicantIncome"])

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
dataset["ApplicantIncome_ss"] = ss.fit_transform(dataset[["ApplicantIncome"]])

# %%
dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History  ApplicantIncome_ss
# count      564.000000        6.140000e+02
# mean         0.842199       -4.339634e-18
# std          0.364878        1.000815e+00
# min          0.000000       -8.606493e-01
# 25%          1.000000       -4.138159e-01
# 50%          1.000000       -2.606393e-01
# ...

# %%
dataset.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status  ApplicantIncome_ss
# 0             1.0         Urban           Y            0.072991
# 1             1.0         Rural           N           -0.134412
# 2             1.0         Urban           Y           -0.393747

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)   # subplot(nrows, ncols, index)

plt.title("Before")
sns.distplot(dataset["ApplicantIncome"])


plt.subplot(1,2,2)
plt.title("After")
sns.distplot(dataset["ApplicantIncome_ss"])
plt.show()
# Out:
# C:\Users\Aahil Khan\AppData\Local\Temp\ipykernel_23212\2124195142.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["ApplicantIncome"])
# C:\Users\Aahil Khan\AppData\Local\Temp\ipykernel_23212\2124195142.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ### Normalization
# - a scaling technique in which values are shifted and rescaled
# - so that they end up ranging between 0 and 1. It is also known
# - as Min-Max scaling.

# %%
Image(filename="normalization.png")

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
dataset["CoapplicantIncome_mm"] = mm.fit_transform(dataset[["CoapplicantIncome"]])

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)

plt.title("Before")
sns.distplot(dataset["CoapplicantIncome"])


plt.subplot(1,2,2)
plt.title("After")
sns.distplot(dataset["CoapplicantIncome_mm"])
plt.show()
# Out:
# C:\Users\Aahil Khan\AppData\Local\Temp\ipykernel_23212\3971952942.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["CoapplicantIncome"])
# C:\Users\Aahil Khan\AppData\Local\Temp\ipykernel_23212\3971952942.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
